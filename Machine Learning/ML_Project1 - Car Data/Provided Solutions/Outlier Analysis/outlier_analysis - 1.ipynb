# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy import math

# %%
auto_org = pd.read_csv('auto_scout_missing.csv')

# %%
df = auto_org.copy()

# %%
df.head(3).T
# Out:
#                                                                          0  \
# make_model                                                         Audi A1
# body_type                                                           Sedans
# price                                                                15770
# vat                                                         VAT deductible
# km                                                                   56013
# prev_owner                                                               2
# hp                                                                      66
# inspection_new                                                           1
# warranty                                                                 0
# body_color                                                           Black
# paint_type                                                        Metallic
# nr_of_doors                                                              5
# nr_of_seats                                                              5
# gearing_type                                                     Automatic
# displacement                                                          1422
# cylinders                                                                3
# weight                                                                1220
# drive_chain                                                          front
# co2_emission                                                            99
# emission_class                                                      Euro 6
# comfort_convenience      'Air conditioning', 'Armrest', 'Automatic clim...
# entertainment_media      'Bluetooth', 'Hands-free equipment', 'On-board...
# extras                   'Alloy wheels', 'Catalytic Converter', 'Voice ...
# safety_security          'ABS', 'Central door lock', 'Daytime running l...
# gears                                                                    7
# electricity_consumption                                                  0
# year                                                                  2016
# new_used                                                              Used
# fuel_type                                                           diesel
# upholstery_material                                                  Cloth
# consumption_comb                                                       3.8
#
#                                                                          1  \
# make_model                                                         Audi A1
# body_type                                                           Sedans
# price                                                                14500
# vat                                                       Price negotiable
# km                                                                   80000
# prev_owner                                                               1
# hp                                                                     141
# inspection_new                                                           0
# warranty                                                                 0
# body_color                                                             Red
# paint_type                                                        Metallic
# nr_of_doors                                                              3
# nr_of_seats                                                              4
# gearing_type                                                     Automatic
# displacement                                                          1798
# cylinders                                                                4
# weight                                                                1255
# drive_chain                                                          front
# co2_emission                                                           129
# emission_class                                                      Euro 6
# comfort_convenience      'Air conditioning', 'Automatic climate control...
# entertainment_media      'Bluetooth', 'Hands-free equipment', 'On-board...
# extras                   'Alloy wheels', 'Sport seats', 'Sport suspensi...
# safety_security          'ABS', 'Central door lock', 'Central door lock...
# gears                                                                    7
# electricity_consumption                                                  0
# year                                                                  2017
# new_used                                                              Used
# fuel_type                                                          benzine
# upholstery_material                                                  Cloth
# consumption_comb                                                       5.6
#
#                                                                          2
# make_model                                                         Audi A1
# body_type                                                           Sedans
# price                                                                14640
# vat                                                         VAT deductible
# km                                                                   83450
# prev_owner                                                               1
# hp                                                                      85
# inspection_new                                                           0
# warranty                                                                 0
# body_color                                                           Black
# paint_type                                                        Metallic
# nr_of_doors                                                              4
# nr_of_seats                                                              4
# gearing_type                                                     Automatic
# displacement                                                          1598
# cylinders                                                                4
# weight                                                                1250
# drive_chain                                                          front
# co2_emission                                                            99
# emission_class                                                      Euro 6
# comfort_convenience      'Air conditioning', 'Cruise control', 'Electri...
# entertainment_media                             'MP3', 'On-board computer'
# extras                                     'Alloy wheels', 'Voice Control'
# safety_security          'ABS', 'Central door lock', 'Daytime running l...
# gears                                                                    7
# electricity_consumption                                                  0
# year                                                                  2016
# new_used                                                              Used
# fuel_type                                                           diesel
# upholstery_material                                                  Cloth
# consumption_comb                                                       3.8

# %% [markdown]
# ## make model - price analysis

# %%
df['make_model'].value_counts(dropna=False)
# Out:
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2525
# Opel Corsa        2216
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %%
df.groupby('make_model').price.mean().sort_values(ascending=False).plot.bar(x='make_model', y='price');

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='price',data=df, x='make_model', hue='year')
# Out:
# <AxesSubplot:xlabel='make_model', ylabel='price'>

# %%
df[(df['make_model']=='Renault Espace')].groupby(['body_type', 'year']).price.max()
# Out:
# body_type      year
# Compact        2016.0    21900
#                2017.0    23990
#                2019.0    43000
# Coupe          2018.0    26994
#                2019.0    34140
# Off-Road       2016.0    14900
#                2017.0    32900
#                2018.0    27850
# Other          2016.0    32900
#                2017.0    27900
#                2018.0    34000
#                2019.0    42681
# Sedans         2016.0    25900
#                2017.0    23990
#                2018.0    36900
#                2019.0    48498
# Station wagon  2016.0    27500
#                2017.0    33900
#                2018.0    39990
#                2019.0    52990
# Transporter    2016.0    30000
#                2017.0    28300
#                2018.0    31000
#                2019.0    32700
# Van            2016.0    68320
#                2017.0    33800
#                2018.0    38990
#                2019.0    64332
# Name: price, dtype: int64

# %%
df[(df['make_model']=='Renault Espace') & (df['year']==2016) & (df['body_type']=='Van')].price.sort_values().tail(20)
# Out:
# 15370    27440
# 14975    27450
# 14972    27500
# 14955    27500
# 14953    27600
# 15345    27900
# 15342    27900
# 15347    27900
# 15285    28140
# 15540    29750
# 15552    30160
# 15303    31000
# 15495    32200
# 15497    32500
# 15484    32600
# 15448    33300
# 15732    35448
# 15766    35930
# 15892    41900
# 15822    68320
# Name: price, dtype: int64

# %%
df.iloc[15822]
# Out:
# make_model                                                    Renault Espace
# body_type                                                                Van
# price                                                                  68320
# vat                                                           VAT deductible
# km                                                                      4307
# prev_owner                                                                 1
# hp                                                                       118
# inspection_new                                                             0
# warranty                                                                  24
# body_color                                                             Black
# paint_type                                                          Metallic
# nr_of_doors                                                                5
# nr_of_seats                                                                4
# gearing_type                                                       Automatic
# displacement                                                            1598
# cylinders                                                                  4
# weight                                                                  1734
# drive_chain                                                            front
# co2_emission                                                             120
# emission_class                                                        Euro 6
# comfort_convenience        'Air conditioning', 'Armrest', 'Automatic clim...
# entertainment_media        'Bluetooth', 'CD player', 'Digital radio', 'Ha...
# extras                                           'Alloy wheels', 'Roof rack'
# safety_security            'ABS', 'Adaptive Cruise Control', 'Adaptive he...
# gears                                                                      7
# electricity_consumption                                                    0
# year                                                                    2016
# new_used                                                       Demonstration
# fuel_type                                                             diesel
# upholstery_material                                             Full leather
# consumption_comb                                                         6.5
# Name: 15822, dtype: object

# %%
df[(df['make_model']=='Audi A3')].groupby(['body_type', 'year']).price.max()
# Out:
# body_type      year
# Compact        2016.0    24950
#                2017.0    67600
#                2018.0    39959
#                2019.0    41495
# Convertible    2016.0    20000
#                2017.0    32950
#                2018.0    56100
# Coupe          2016.0    18000
#                2017.0    19000
# Other          2016.0    18500
#                2017.0    20500
#                2018.0    28490
#                2019.0    26990
# Sedans         2016.0    42500
#                2017.0    55000
#                2018.0    74600
#                2019.0    62900
# Station wagon  2016.0    18780
#                2017.0    21990
#                2018.0    23800
#                2019.0    63900
# Name: price, dtype: int64

# %%
last4 = df[(df['make_model']=='Audi A3') & (df['year']==2018) & (df['body_type']=='Sedans')].price.sort_values().tail(4).index

# %%
df.iloc[last4]
# Out:
#      make_model body_type  price               vat       km  prev_owner  \
# 3593    Audi A3    Sedans  58500  VAT undeductible  10000.0         1.0
# 3594    Audi A3    Sedans  58990    VAT deductible   7500.0         1.0
# 3587    Audi A3    Sedans  64900  VAT undeductible  35000.0         1.0
# 3648    Audi A3    Sedans  74600    VAT deductible  13000.0         1.0
#
#          hp  inspection_new  warranty body_color  ...  \
# 3593  294.0               0       0.0      White  ...
# 3594  228.0               0       0.0       Blue  ...
# 3587  294.0               0       0.0       Grey  ...
# 3648  294.0               0       0.0      Black  ...
#
#                                     entertainment_media  \
# 3593                                            'Radio'
# 3594  'Bluetooth', 'CD player', 'Hands-free equipmen...
# 3587                                            'Radio'
# 3648          'CD player', 'On-board computer', 'Radio'
#
#                                                  extras  \
# 3593                                     'Alloy wheels'
# 3594  'Alloy wheels', 'Sport package', 'Sport seats'...
# 3587                                     'Alloy wheels'
# 3648  'Alloy wheels', 'Sport seats', 'Sport suspension'
#
#                                         safety_security gears  \
# 3593  'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3594  'ABS', 'Adaptive Cruise Control', 'Adaptive he...   7.0
# 3587  'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3648  'ABS', 'Alarm system', 'Central door lock', 'D...   7.0
#
#       electricity_consumption    year  new_used fuel_type  \
# 3593                        0  2018.0      Used   benzine
# 3594                        0  2018.0      Used   benzine
# 3587                        0  2018.0      Used   benzine
# 3648                        0  2018.0      Used   benzine
#
#       upholstery_material consumption_comb
# 3593                  NaN              8.3
# 3594         Full leather              6.5
# 3587                  NaN              8.3
# 3648         Full leather              8.3
#
# [4 rows x 31 columns]

# %% [markdown]
# ## km

# %%
plt.figure(figsize=(8,6))
df.boxplot(column = ['km']);

# %% [markdown]
# ## hp

# %%
sns.boxplot(y='hp',data=df);

# %%
df[df['hp']<50]
# Out:
#            make_model      body_type  price               vat        km  \
# 3913          Audi A3         Sedans  20440  VAT undeductible   24000.0
# 6005       Opel Astra  Station wagon  11600  VAT undeductible   73860.0
# 6034       Opel Astra  Station wagon  11600  VAT undeductible   76010.0
# 6945       Opel Astra  Station wagon  11900  VAT undeductible   70090.0
# 7013       Opel Astra         Sedans  11700  VAT undeductible   79993.0
# 7015       Opel Astra         Sedans  11700  VAT undeductible   62384.0
# 7017       Opel Astra         Sedans  11700  VAT undeductible   77272.0
# 7018       Opel Astra         Sedans  11700  VAT undeductible   69035.0
# 8407       Opel Corsa        Compact  12435    VAT deductible   21050.0
# 8853       Opel Corsa        Compact   7650  VAT undeductible     142.0
# 9281       Opel Corsa         Sedans   8300  VAT undeductible   58912.0
# 9283       Opel Corsa         Sedans   8300  VAT undeductible   53522.0
# 9284       Opel Corsa         Sedans   8300  VAT undeductible   60386.0
# 9285       Opel Corsa         Sedans   8300  VAT undeductible   59217.0
# 9286       Opel Corsa         Sedans   8300  VAT undeductible   51318.0
# 9288       Opel Corsa         Sedans   8300  VAT undeductible   53390.0
# 9295       Opel Corsa         Sedans   8300  VAT undeductible   47140.0
# 10464   Opel Insignia  Station wagon  15300  VAT undeductible   77125.0
# 10575   Opel Insignia  Station wagon  16400  VAT undeductible   78762.0
# 10576   Opel Insignia  Station wagon  16400  VAT undeductible   68525.0
# 10606   Opel Insignia  Station wagon  15300  VAT undeductible   62800.0
# 13755    Renault Clio        Compact   5890  VAT undeductible  134500.0
# 13881    Renault Clio        Compact   8990  VAT undeductible    9751.0
# 15151  Renault Espace         Sedans  23800  VAT undeductible   56340.0
# 15152  Renault Espace         Sedans  23800  VAT undeductible   69600.0
#
#        prev_owner    hp  inspection_new  warranty body_color  ...  \
# 3913          1.0   9.0               0       0.0      Black  ...
# 6005          1.0   1.0               0       0.0      Black  ...
# 6034          1.0   1.0               0       0.0     Silver  ...
# 6945          1.0   1.0               0       0.0      Black  ...
# 7013          1.0   1.0               0       0.0     Silver  ...
# 7015          1.0   1.0               0       0.0      Black  ...
# 7017          1.0   1.0               0       0.0      Black  ...
# 7018          1.0   1.0               0       0.0      Black  ...
# 8407          1.0  44.0               1       0.0      White  ...
# 8853          1.0  40.0               0      12.0       Grey  ...
# 9281          1.0   1.0               0       0.0      Black  ...
# 9283          1.0   1.0               0       0.0     Silver  ...
# 9284          1.0   1.0               0       0.0     Silver  ...
# 9285          1.0   1.0               0       0.0     Silver  ...
# 9286          1.0   1.0               0       0.0     Silver  ...
# 9288          1.0   1.0               0       0.0     Silver  ...
# 9295          1.0   1.0               0       0.0      Black  ...
# 10464         1.0   1.0               0       0.0      Black  ...
# 10575         1.0   1.0               0       0.0     Silver  ...
# 10576         1.0   1.0               0       0.0     Silver  ...
# 10606         1.0   1.0               0       0.0     Silver  ...
# 13755         1.0  40.0               0      12.0      White  ...
# 13881         1.0   4.0               0      12.0       Grey  ...
# 15151         1.0   1.0               0       0.0       Grey  ...
# 15152         1.0   1.0               0       0.0      Black  ...
#
#                                      entertainment_media  \
# 3913                                                 NaN
# 6005    'Bluetooth', 'On-board computer', 'Radio', 'USB'
# 6034    'Bluetooth', 'On-board computer', 'Radio', 'USB'
# 6945   'Bluetooth', 'CD player', 'On-board computer',...
# 7013                                'CD player', 'Radio'
# 7015                                'CD player', 'Radio'
# 7017                                'CD player', 'Radio'
# 7018                                'CD player', 'Radio'
# 8407   'Bluetooth', 'CD player', 'Hands-free equipmen...
# 8853                                                 NaN
# 9281   'Bluetooth', 'CD player', 'On-board computer',...
# 9283   'Bluetooth', 'CD player', 'On-board computer',...
# 9284   'Bluetooth', 'CD player', 'On-board computer',...
# 9285   'Bluetooth', 'CD player', 'On-board computer',...
# 9286   'Bluetooth', 'CD player', 'On-board computer',...
# 9288   'Bluetooth', 'CD player', 'On-board computer',...
# 9295   'Bluetooth', 'CD player', 'On-board computer',...
# 10464  'Bluetooth', 'CD player', 'On-board computer',...
# 10575  'Bluetooth', 'CD player', 'On-board computer',...
# 10576  'Bluetooth', 'CD player', 'On-board computer',...
# 10606  'Bluetooth', 'CD player', 'On-board computer',...
# 13755                                                NaN
# 13881                                'On-board computer'
# 15151  'Bluetooth', 'CD player', 'On-board computer',...
# 15152  'Bluetooth', 'CD player', 'On-board computer',...
#
#                               extras  \
# 3913                             NaN
# 6005                             NaN
# 6034                             NaN
# 6945                             NaN
# 7013                             NaN
# 7015                             NaN
# 7017                             NaN
# 7018                             NaN
# 8407   'Alloy wheels', 'Sport seats'
# 8853                  'Alloy wheels'
# 9281                             NaN
# 9283                             NaN
# 9284                             NaN
# 9285                             NaN
# 9286                             NaN
# 9288                             NaN
# 9295                             NaN
# 10464                            NaN
# 10575                            NaN
# 10576                            NaN
# 10606                            NaN
# 13755                            NaN
# 13881                            NaN
# 15151                            NaN
# 15152                            NaN
#
#                                          safety_security gears  \
# 3913                                                 NaN   7.0
# 6005   'Alarm system', 'Central door lock', 'Driver-s...   6.0
# 6034   'Alarm system', 'Central door lock', 'Driver-s...   6.0
# 6945   'Central door lock', 'Driver-side airbag', 'El...   6.0
# 7013   'Driver-side airbag', 'Electronic stability co...   6.0
# 7015   'Driver-side airbag', 'Electronic stability co...   6.0
# 7017   'Driver-side airbag', 'Electronic stability co...   6.0
# 7018   'Driver-side airbag', 'Electronic stability co...   6.0
# 8407   'ABS', 'Central door lock', 'Daytime running l...   5.0
# 8853   'ABS', 'Central door lock', 'Driver-side airba...   5.0
# 9281   'Alarm system', 'Central door lock', 'Driver-s...   5.0
# 9283   'Alarm system', 'Central door lock', 'Driver-s...   5.0
# 9284   'Alarm system', 'Central door lock', 'Driver-s...   5.0
# 9285   'Alarm system', 'Central door lock', 'Driver-s...   5.0
# 9286   'Alarm system', 'Central door lock', 'Driver-s...   5.0
# 9288   'Alarm system', 'Central door lock', 'Driver-s...   5.0
# 9295   'Alarm system', 'Central door lock', 'Driver-s...   5.0
# 10464  'Alarm system', 'Central door lock', 'Driver-s...   6.0
# 10575  'Alarm system', 'Central door lock', 'Driver-s...   6.0
# 10576  'Alarm system', 'Central door lock', 'Driver-s...   6.0
# 10606  'Alarm system', 'Central door lock', 'Driver-s...   6.0
# 13755  'ABS', 'Central door lock', 'Driver-side airba...   5.0
# 13881  'ABS', 'Driver-side airbag', 'Immobilizer', 'P...   5.0
# 15151  'Alarm system', 'Central door lock', 'Driver-s...   6.0
# 15152  'Alarm system', 'Central door lock', 'Driver-s...   6.0
#
#        electricity_consumption    year  new_used fuel_type  \
# 3913                         0  2017.0      Used    diesel
# 6005                         0  2017.0      Used   benzine
# 6034                         0  2017.0      Used   benzine
# 6945                         0  2017.0      Used    diesel
# 7013                         0  2017.0      Used   benzine
# 7015                         0  2017.0      Used   benzine
# 7017                         0  2017.0      Used   benzine
# 7018                         0  2017.0      Used   benzine
# 8407                         0  2018.0      Used   benzine
# 8853                         0  2019.0       New   benzine
# 9281                         0  2017.0      Used   benzine
# 9283                         0  2017.0      Used   benzine
# 9284                         0  2017.0      Used   benzine
# 9285                         0  2017.0      Used   benzine
# 9286                         0  2017.0      Used   benzine
# 9288                         0  2017.0      Used   benzine
# 9295                         0  2017.0      Used   benzine
# 10464                        0  2017.0      Used    diesel
# 10575                        0  2017.0      Used    diesel
# 10576                        0  2017.0      Used    diesel
# 10606                        0  2017.0      Used    diesel
# 13755                        0  2016.0      Used    diesel
# 13881                        0  2017.0      Used   benzine
# 15151                        0  2017.0      Used    diesel
# 15152                        0  2017.0      Used    diesel
#
#        upholstery_material consumption_comb
# 3913                   NaN              3.8
# 6005                   NaN              4.4
# 6034                   NaN              4.4
# 6945                   NaN              4.5
# 7013                   NaN              6.8
# 7015                   NaN              6.8
# 7017                   NaN              6.8
# 7018                   NaN              6.8
# 8407                 Cloth              6.0
# 8853                 Other              5.4
# 9281                   NaN              5.3
# 9283                   NaN              5.3
# 9284                   NaN              5.3
# 9285                   NaN              5.3
# 9286                   NaN              5.3
# 9288                   NaN              5.3
# 9295                   NaN              5.3
# 10464                  NaN              5.0
# 10575                  NaN              5.0
# 10576                  NaN              5.0
# 10606                  NaN              5.0
# 13755                  NaN              3.3
# 13881                  NaN              5.4
# 15151                  NaN              5.4
# 15152                  NaN              5.4
#
# [25 rows x 31 columns]

# %%
df.loc[df['hp']<50,'hp'] = np.nan

# %%
df[df['hp']>200]
# Out:
#           make_model      body_type  price               vat        km  \
# 3587         Audi A3         Sedans  64900  VAT undeductible   35000.0
# 3590         Audi A3         Sedans  62900  VAT undeductible     700.0
# 3592         Audi A3         Sedans  56900  VAT undeductible    5200.0
# 3593         Audi A3         Sedans  58500  VAT undeductible   10000.0
# 3594         Audi A3         Sedans  58990    VAT deductible    7500.0
# 3595         Audi A3  Station wagon  63900    VAT deductible      10.0
# 3596         Audi A3         Sedans  57400  Price negotiable   63000.0
# 3597         Audi A3    Convertible  56100    VAT deductible    8364.0
# 3598         Audi A3         Sedans  55000    VAT deductible   24000.0
# 3599         Audi A3         Sedans  55000  VAT undeductible   30000.0
# 3600         Audi A3         Sedans  53000  VAT undeductible    4000.0
# 3601         Audi A3         Sedans  51900  VAT undeductible   19000.0
# 3602         Audi A3         Sedans  51900    VAT deductible   49000.0
# 3603         Audi A3         Sedans  52000  VAT undeductible   13963.0
# 3604         Audi A3         Sedans  50000  VAT undeductible   25000.0
# 3605         Audi A3         Sedans  51999  VAT undeductible   33000.0
# 3606         Audi A3         Sedans  49900    VAT deductible   17234.0
# 3608         Audi A3         Sedans  42500  Price negotiable   37333.0
# 3609         Audi A3         Sedans  41000  VAT undeductible   30000.0
# 3610         Audi A3         Sedans  45890  VAT undeductible   18700.0
# 3648         Audi A3         Sedans  74600    VAT deductible   13000.0
# 3649         Audi A3        Compact  67600    VAT deductible   37747.0
# 10509  Opel Insignia  Station wagon  17990    VAT deductible  145000.0
#
#        prev_owner     hp  inspection_new  warranty body_color  ...  \
# 3587          1.0  294.0               0       0.0       Grey  ...
# 3590          1.0  294.0               0       0.0       Grey  ...
# 3592          1.0  294.0               0       0.0       Grey  ...
# 3593          1.0  294.0               0       0.0      White  ...
# 3594          1.0  228.0               0       0.0       Blue  ...
# 3595          0.0  294.0               0      24.0      Black  ...
# 3596          1.0  294.0               0       0.0       Blue  ...
# 3597          1.0  228.0               0       0.0       Blue  ...
# 3598          1.0  294.0               0       0.0      Black  ...
# 3599          1.0  294.0               0       0.0       Grey  ...
# 3600          1.0  294.0               0       0.0      Black  ...
# 3601          1.0  294.0               0       0.0      Black  ...
# 3602          1.0  294.0               0      12.0     Silver  ...
# 3603          1.0  294.0               0       0.0       Grey  ...
# 3604          1.0  294.0               0       0.0       Grey  ...
# 3605          1.0  294.0               0       0.0      White  ...
# 3606          1.0  294.0               0       0.0      Black  ...
# 3608          1.0  270.0               0       0.0       Grey  ...
# 3609          1.0  270.0               0       0.0       Blue  ...
# 3610          1.0  294.0               0       0.0      White  ...
# 3648          1.0  294.0               0       0.0      Black  ...
# 3649          1.0  294.0               0       0.0      White  ...
# 10509         1.0  239.0               0       0.0        Red  ...
#
#                                      entertainment_media  \
# 3587                                             'Radio'
# 3590                                'Bluetooth', 'Radio'
# 3592   'Bluetooth', 'CD player', 'Digital radio', 'Ha...
# 3593                                             'Radio'
# 3594   'Bluetooth', 'CD player', 'Hands-free equipmen...
# 3595   'Bluetooth', 'CD player', 'Digital radio', 'Ha...
# 3596   'Bluetooth', 'CD player', 'Hands-free equipmen...
# 3597           'CD player', 'On-board computer', 'Radio'
# 3598                                             'Radio'
# 3599                                             'Radio'
# 3600   'Bluetooth', 'CD player', 'Digital radio', 'Ha...
# 3601   'Bluetooth', 'Digital radio', 'Hands-free equi...
# 3602   'Bluetooth', 'Digital radio', 'Hands-free equi...
# 3603   'Bluetooth', 'CD player', 'Hands-free equipmen...
# 3604   'Bluetooth', 'CD player', 'Hands-free equipmen...
# 3605   'Bluetooth', 'CD player', 'Digital radio', 'Ha...
# 3606                                             'Radio'
# 3608                                         'Bluetooth'
# 3609   'Bluetooth', 'Digital radio', 'On-board computer'
# 3610                                             'Radio'
# 3648           'CD player', 'On-board computer', 'Radio'
# 3649           'CD player', 'On-board computer', 'Radio'
# 10509  'Bluetooth', 'CD player', 'Digital radio', 'Ha...
#
#                                                   extras  \
# 3587                                      'Alloy wheels'
# 3590                                      'Alloy wheels'
# 3592   'Alloy wheels', 'Shift paddles', 'Sport packag...
# 3593                                      'Alloy wheels'
# 3594   'Alloy wheels', 'Sport package', 'Sport seats'...
# 3595   'Alloy wheels', 'Shift paddles', 'Ski bag', 'S...
# 3596   'Alloy wheels', 'Sport seats', 'Sport suspensi...
# 3597   'Alloy wheels', 'Shift paddles', 'Sport seats'...
# 3598                                      'Alloy wheels'
# 3599                                      'Alloy wheels'
# 3600   'Alloy wheels', 'Catalytic Converter', 'Shift ...
# 3601   'Alloy wheels', 'Catalytic Converter', 'Shift ...
# 3602   'Alloy wheels', 'Shift paddles', 'Sport packag...
# 3603   'Alloy wheels', 'Sliding door', 'Sport package...
# 3604   'Alloy wheels', 'Shift paddles', 'Sport packag...
# 3605   'Alloy wheels', 'Catalytic Converter', 'Shift ...
# 3606                                      'Alloy wheels'
# 3608                                      'Alloy wheels'
# 3609   'Alloy wheels', 'Shift paddles', 'Sport packag...
# 3610                                      'Alloy wheels'
# 3648   'Alloy wheels', 'Sport seats', 'Sport suspension'
# 3649   'Alloy wheels', 'Roof rack', 'Sport seats', 'S...
# 10509  'Alloy wheels', 'Roof rack', 'Shift paddles', ...
#
#                                          safety_security gears  \
# 3587   'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3590   'ABS', 'Adaptive Cruise Control', 'Alarm syste...   7.0
# 3592   'ABS', 'Adaptive Cruise Control', 'Adaptive he...   7.0
# 3593   'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3594   'ABS', 'Adaptive Cruise Control', 'Adaptive he...   7.0
# 3595   'ABS', 'Adaptive Cruise Control', 'Adaptive he...   7.0
# 3596   'ABS', 'Adaptive Cruise Control', 'Adaptive he...   7.0
# 3597   'ABS', 'Alarm system', 'Central door lock', 'D...   7.0
# 3598   'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3599   'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3600   'Adaptive Cruise Control', 'Adaptive headlight...   7.0
# 3601   'ABS', 'Adaptive Cruise Control', 'Adaptive he...   7.0
# 3602   'ABS', 'Adaptive Cruise Control', 'Alarm syste...   7.0
# 3603   'Adaptive Cruise Control', 'Adaptive headlight...   7.0
# 3604   'ABS', 'Adaptive Cruise Control', 'Alarm syste...   7.0
# 3605   'ABS', 'Adaptive Cruise Control', 'Adaptive he...   7.0
# 3606   'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3608   'ABS', 'Alarm system', 'Central door lock', 'D...   7.0
# 3609   'ABS', 'Adaptive Cruise Control', 'Alarm syste...   7.0
# 3610   'Adaptive Cruise Control', 'Alarm system', 'Ce...   7.0
# 3648   'ABS', 'Alarm system', 'Central door lock', 'D...   7.0
# 3649   'ABS', 'Alarm system', 'Central door lock', 'D...   7.0
# 10509  'ABS', 'Adaptive Cruise Control', 'Blind spot ...   6.0
#
#        electricity_consumption    year  new_used fuel_type  \
# 3587                         0  2018.0      Used   benzine
# 3590                         0  2019.0      Used   benzine
# 3592                         0  2018.0      Used   benzine
# 3593                         0  2018.0      Used   benzine
# 3594                         0  2018.0      Used   benzine
# 3595                         0  2019.0      Used   benzine
# 3596                         0  2018.0      Used   benzine
# 3597                         0  2018.0      Used   benzine
# 3598                         0  2017.0      Used   benzine
# 3599                         0  2018.0      Used   benzine
# 3600                         0  2018.0      Used   benzine
# 3601                         0  2017.0      Used   benzine
# 3602                         0  2018.0      Used   benzine
# 3603                         0  2018.0      Used   benzine
# 3604                         0  2018.0      Used   benzine
# 3605                         0  2017.0      Used   benzine
# 3606                         0  2018.0      Used   benzine
# 3608                         0  2016.0      Used   benzine
# 3609                         0  2016.0      Used   benzine
# 3610                         0  2018.0      Used   benzine
# 3648                         0  2018.0      Used   benzine
# 3649                         0  2017.0      Used   benzine
# 10509                        0  2016.0      Used   benzine
#
#        upholstery_material consumption_comb
# 3587                   NaN              8.3
# 3590                   NaN              8.3
# 3592          Full leather              8.3
# 3593                   NaN              8.3
# 3594          Full leather              6.5
# 3595          Part leather              8.3
# 3596          Full leather              8.3
# 3597          Part leather              7.1
# 3598                   NaN              8.3
# 3599                   NaN              8.3
# 3600                   NaN              8.3
# 3601                   NaN              8.3
# 3602          Full leather              8.3
# 3603                   NaN              8.3
# 3604                   NaN              8.3
# 3605          Full leather              8.3
# 3606                   NaN              8.3
# 3608                   NaN              8.1
# 3609                   NaN              8.1
# 3610                   NaN              8.3
# 3648          Full leather              8.3
# 3649          Full leather              8.3
# 10509         Full leather             11.0
#
# [23 rows x 31 columns]

# %%
mode_hp = df.groupby(['make_model','body_type','displacement'])['hp']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df["hp"] = df["hp"].fillna(mode_hp)

# %%
mode_hp1 = df.groupby(['make_model','displacement'])['hp']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df["hp"] = df["hp"].fillna(mode_hp1)

# %%
mode_hp2 = df.groupby(['make_model','body_type'])['hp']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df["hp"] = df["hp"].fillna(mode_hp2)

# %% [markdown]
# ## body color

# %%
df.body_color.value_counts()
# Out:
# Black     3941
# Grey      3838
# White     3468
# Silver    1647
# Blue      1431
# Red        957
# Brown      289
# Green      158
# Beige      108
# Yellow      51
# Violet      18
# Bronze       6
# Orange       3
# Name: body_color, dtype: int64

# %%
df.body_color = df.body_color.replace(['Yellow','Violet','Bronze','Orange'], 'Others')

# %%
df.body_color.value_counts()
# Out:
# Black     3941
# Grey      3838
# White     3468
# Silver    1647
# Blue      1431
# Red        957
# Brown      289
# Green      158
# Beige      108
# Others      78
# Name: body_color, dtype: int64

# %% [markdown]
# ## nr_of_doors

# %%
df.nr_of_doors.value_counts()
# Out:
# 5.0    11784
# 4.0     3079
# 3.0      831
# 2.0      219
# 7.0        1
# 1.0        1
# Name: nr_of_doors, dtype: int64

# %%
df[df.nr_of_doors == 1]
# Out:
#          make_model body_type  price             vat       km  prev_owner  \
# 13778  Renault Clio   Compact   8500  VAT deductible  41493.0         1.0
#
#          hp  inspection_new  warranty body_color  ... entertainment_media  \
# 13778  55.0               0      12.0      White  ...                 NaN
#
#        extras  safety_security gears  electricity_consumption    year  \
# 13778     NaN              NaN   5.0                        0  2016.0
#
#        new_used fuel_type  upholstery_material consumption_comb
# 13778      Used    diesel                  NaN              3.3
#
# [1 rows x 31 columns]

# %%
df.loc[(df['make_model'] == 'Renault Clio') & (df['body_type'] == 'Compact'), ['nr_of_doors']].value_counts()
# Out:
# nr_of_doors
# 5.0            313
# 4.0            170
# 1.0              1
# dtype: int64

# %%
df.loc[df.nr_of_doors == 1,'nr_of_doors'] = 5

# %%
df.nr_of_doors.value_counts()
# Out:
# 5.0    11785
# 4.0     3079
# 3.0      831
# 2.0      219
# 7.0        1
# Name: nr_of_doors, dtype: int64

# %%
df[df.nr_of_doors == 7]
# Out:
#            make_model body_type  price               vat       km  prev_owner  \
# 15198  Renault Espace       Van  21600  Price negotiable  78000.0         1.0
#
#           hp  inspection_new  warranty body_color  ...  \
# 15198  118.0               0       0.0      Brown  ...
#
#                                      entertainment_media  \
# 15198  'Bluetooth', 'Digital radio', 'MP3', 'On-board...
#
#                                extras  \
# 15198  'Alloy wheels', 'Touch screen'
#
#                                          safety_security gears  \
# 15198  'ABS', 'Blind spot monitor', 'Central door loc...   6.0
#
#        electricity_consumption    year  new_used fuel_type  \
# 15198                        0  2016.0      Used    diesel
#
#        upholstery_material consumption_comb
# 15198         Full leather              4.6
#
# [1 rows x 31 columns]

# %%
df.loc[df.nr_of_doors == 4,'nr_of_doors'] = 5

# %%
df.loc[df.nr_of_doors == 7,'nr_of_doors'] = 5

# %%
df.loc[df.nr_of_doors == 2,'nr_of_doors'] = 3

# %%
df.nr_of_doors.value_counts()
# Out:
# 5.0    14865
# 3.0     1050
# Name: nr_of_doors, dtype: int64

# %% [markdown]
# ## nr_of_seats

# %%
df.nr_of_seats.value_counts()
# Out:
# 5.0    14304
# 4.0     1127
# 7.0      362
# 2.0      119
# 6.0        2
# 3.0        1
# Name: nr_of_seats, dtype: int64

# %%
df.loc[df.nr_of_seats == 3]
# Out:
#      make_model body_type  price               vat      km  prev_owner     hp  \
# 1636    Audi A1   Compact  23090  VAT undeductible  9821.0         1.0  141.0
#
#       inspection_new  warranty body_color  ...  \
# 1636               1       0.0      Black  ...
#
#                                     entertainment_media  \
# 1636  'Bluetooth', 'CD player', 'Digital radio', 'Ha...
#
#                                                  extras  \
# 1636  'Alloy wheels', 'Catalytic Converter', 'Sport ...
#
#                                         safety_security gears  \
# 1636  'ABS', 'Central door lock', 'Daytime running l...   7.0
#
#       electricity_consumption    year  new_used fuel_type  \
# 1636                        0  2018.0      Used   benzine
#
#       upholstery_material consumption_comb
# 1636         Part leather              5.8
#
# [1 rows x 31 columns]

# %%
df.loc[df.nr_of_seats == 3,'nr_of_seats'] = 4

# %%
df.loc[df.nr_of_seats == 6]
# Out:
#            make_model      body_type  price             vat        km  \
# 582           Audi A1        Compact  13500  VAT deductible  100000.0
# 15886  Renault Espace  Station wagon  42490  VAT deductible    2000.0
#
#        prev_owner     hp  inspection_new  warranty body_color  ...  \
# 582           1.0   70.0               0      12.0      White  ...
# 15886         1.0  147.0               0       0.0      Black  ...
#
#                                      entertainment_media  \
# 582                                  'On-board computer'
# 15886  'Bluetooth', 'Hands-free equipment', 'On-board...
#
#                                extras  \
# 582                    'Alloy wheels'
# 15886  'Alloy wheels', 'Touch screen'
#
#                                          safety_security gears  \
# 582                                                'ABS'   5.0
# 15886  'ABS', 'Blind spot monitor', 'Central door loc...   6.0
#
#        electricity_consumption    year  new_used fuel_type  \
# 582                          0  2017.0      Used   benzine
# 15886                        0  2019.0       New    diesel
#
#        upholstery_material consumption_comb
# 582                    NaN              4.2
# 15886                Cloth              5.7
#
# [2 rows x 31 columns]

# %%
df.loc[582,'nr_of_seats'] = 4

# %% [markdown]
# ## displacement

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='displacement',data=df, x='make_model');

# %%
df.loc[df.displacement>5000, 'displacement'] = np.nan

# %%
df.loc[df.displacement<600, 'displacement'] = np.nan

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='displacement',data=df, x='make_model');

# %%
mode_disp = df.groupby(['make_model','body_type','hp'])['displacement']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df["displacement"] = df["displacement"].fillna(mode_disp)

# %% [markdown]
# ## cylinders

# %%
df["cylinders"].value_counts()
# Out:
# 4.0    12438
# 3.0     3447
# 5.0       22
# 6.0        3
# 2.0        2
# 8.0        2
# 1.0        1
# Name: cylinders, dtype: int64

# %%
df.loc[df["cylinders"]<3,'make_model':'displacement']
# Out:
#            make_model      body_type  price             vat       km  \
# 9952       Opel Corsa        Compact  16625  VAT deductible    100.0
# 11338   Opel Insignia  Station wagon  21900  VAT deductible  13600.0
# 15831  Renault Espace            Van  47590  VAT deductible   6000.0
#
#        prev_owner     hp  inspection_new  warranty body_color paint_type  \
# 9952          1.0   66.0               0       0.0      Black   Metallic
# 11338         1.0  100.0               0       0.0       Grey   Metallic
# 15831         1.0  147.0               0       0.0      Black   Metallic
#
#        nr_of_doors  nr_of_seats gearing_type  displacement
# 9952           3.0          5.0    Automatic        1398.0
# 11338          5.0          5.0    Automatic        1598.0
# 15831          5.0          7.0    Automatic        1997.0

# %%
df[df.make_model == 'Opel Insignia'].cylinders.value_counts()
# Out:
# 4.0    2594
# 6.0       3
# 2.0       1
# Name: cylinders, dtype: int64

# %%
df[df.make_model == 'Opel Corsa'].cylinders.value_counts()
# Out:
# 4.0    2170
# 3.0      45
# 1.0       1
# Name: cylinders, dtype: int64

# %%
df.loc[df["cylinders"]<3,'cylinders'] = 4

# %%
df.loc[df["cylinders"]>5,'make_model':'cylinders']
# Out:
#            make_model      body_type  price               vat        km  \
# 535           Audi A1        Compact  12990  VAT undeductible   41200.0
# 10767   Opel Insignia  Station wagon  12000  Price negotiable  185000.0
# 10822   Opel Insignia  Station wagon  12500  Price negotiable   77500.0
# 12893   Opel Insignia         Sedans  26500    VAT deductible       5.0
# 15051  Renault Espace            Van  24990  VAT undeductible   47423.0
#
#        prev_owner     hp  inspection_new  warranty body_color paint_type  \
# 535           1.0   70.0               1       0.0     Silver   Metallic
# 10767         1.0  100.0               0       0.0      White   Metallic
# 10822         1.0  100.0               0       0.0       Grey   Metallic
# 12893         0.0  100.0               0      12.0       Grey  Uni/basic
# 15051         1.0  117.0               0       3.0      Black   Metallic
#
#        nr_of_doors  nr_of_seats gearing_type  displacement  cylinders
# 535            5.0          5.0       Manual         999.0        8.0
# 10767          5.0          5.0    Automatic        2967.0        6.0
# 10822          5.0          5.0    Automatic        1598.0        6.0
# 12893          5.0          5.0       Manual        1600.0        6.0
# 15051          5.0          5.0    Automatic        1598.0        8.0

# %% [markdown]
# ## weight

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='weight',data=df, x='make_model');

# %%
df[df.weight<600]
# Out:
#           make_model      body_type  price               vat      km  \
# 1143         Audi A1        Compact  19229    VAT deductible  8263.0
# 8354      Opel Corsa        Compact  12945  VAT undeductible  2015.0
# 12775  Opel Insignia  Station wagon  39299    VAT deductible    10.0
#
#        prev_owner     hp  inspection_new  warranty body_color  ...  \
# 1143          1.0   70.0               1      36.0      Beige  ...
# 8354          1.0   66.0               1       0.0     Silver  ...
# 12775         0.0  121.0               0       0.0      Black  ...
#
#                                      entertainment_media  \
# 1143   'Bluetooth', 'CD player', 'Hands-free equipmen...
# 8354                                             'Radio'
# 12775                                                NaN
#
#                                                   extras  \
# 1143   'Alloy wheels', 'Catalytic Converter', 'Sport ...
# 8354                               'Catalytic Converter'
# 12775                                                NaN
#
#                                          safety_security gears  \
# 1143   'ABS', 'Central door lock', 'Daytime running l...   7.0
# 8354   'ABS', 'Central door lock', 'Daytime running l...   5.0
# 12775      'Fog lights', 'Lane departure warning system'   6.0
#
#        electricity_consumption    year  new_used fuel_type  \
# 1143                         0  2018.0      Used   benzine
# 8354                         0  2018.0      Used   benzine
# 12775                        0  2019.0       New   benzine
#
#        upholstery_material consumption_comb
# 1143                 Cloth              4.6
# 8354                 Cloth              4.8
# 12775                Cloth              6.0
#
# [3 rows x 31 columns]

# %%
df.loc[1143,'weight'] = 1200

# %%
df.loc[8354,'weight'] = 1200

# %%
df.loc[12775,'weight'] = 1600

# %%
df[df.weight<500]
# Out:
# Empty DataFrame
# Columns: [make_model, body_type, price, vat, km, prev_owner, hp, inspection_new, warranty, body_color, paint_type, nr_of_doors, nr_of_seats, gearing_type, displacement, cylinders, weight, drive_chain, co2_emission, emission_class, comfort_convenience, entertainment_media, extras, safety_security, gears, electricity_consumption, year, new_used, fuel_type, upholstery_material, consumption_comb]
# Index: []
#
# [0 rows x 31 columns]

# %% [markdown]
# ## drive_chain

# %%
df.drive_chain.value_counts()
# Out:
# front    15707
# 4WD        204
# rear         4
# Name: drive_chain, dtype: int64

# %% [markdown]
# ## co2_emission

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='co2_emission',data=df, x='make_model');

# %%
df.loc[df.co2_emission>300,'co2_emission'] = np.nan

# %%
df.loc[df.co2_emission<70,'co2_emission'] = np.nan

# %%
mode_CO2 = df.groupby(['make_model','displacement'])['co2_emission']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df['co2_emission'] = df['co2_emission'].fillna(mode_CO2)

# %%
mode_CO2_1 = df.groupby(['make_model'])['co2_emission']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df['co2_emission'] = df['co2_emission'].fillna(mode_CO2_1)

# %%
mode_CO2_2 = df.groupby(['body_type'])['co2_emission']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df['co2_emission'] = df['co2_emission'].fillna(mode_CO2_2)

# %%
df['co2_emission'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='co2_emission',data=df, x='make_model');

# %% [markdown]
# ## Gears

# %%
df.gears.value_counts()
# Out:
# 6.0     8614
# 5.0     4253
# 7.0     2810
# 8.0      224
# 9.0        6
# 4.0        2
# 3.0        2
# 1.0        2
# 50.0       1
# 2.0        1
# Name: gears, dtype: int64

# %%
df.loc[df.gears==50,'gears'] = 5

# %%
df.loc[df.gears<5,'gears'] = 5

# %%
df.gears.value_counts()
# Out:
# 6.0    8614
# 5.0    4261
# 7.0    2810
# 8.0     224
# 9.0       6
# Name: gears, dtype: int64

# %% [markdown]
# ## consumption_comb

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='consumption_comb',data=df, x='make_model');

# %%
df.loc[(df['consumption_comb']>20 ),'consumption_comb'] = np.nan

# %%
df.loc[(df['consumption_comb']<3 ),'consumption_comb'] = np.nan

# %%
mode_Cons= df.groupby(['co2_emission'])['consumption_comb']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df['consumption_comb'] = df['consumption_comb'].fillna(mode_Cons)

# %%
mode_Cons1= df.groupby(['displacement'])['consumption_comb']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df['consumption_comb'] = df['consumption_comb'].fillna(mode_Cons1)

# %%
mode_Cons2= df.groupby(['make_model'])['consumption_comb']\
              .transform(lambda x: x.mode()[0] if list(x.mode()) != [] else np.nan)

# %%
df['consumption_comb'] = df['consumption_comb'].fillna(mode_Cons2)

# %%
df['consumption_comb'].isnull().sum()
# Out:
# 0

# %%
df.to_csv('auto_scout_outlier.csv', index=False)

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'price', 'vat', 'km', 'prev_owner', 'hp',
#        'inspection_new', 'warranty', 'body_color', 'paint_type', 'nr_of_doors',
#        'nr_of_seats', 'gearing_type', 'displacement', 'cylinders', 'weight',
#        'drive_chain', 'co2_emission', 'emission_class', 'comfort_convenience',
#        'entertainment_media', 'extras', 'safety_security', 'gears',
#        'electricity_consumption', 'age', 'new_used', 'fuel_type',
#        'upholstery_material', 'consumption_comb'],
#       dtype='object')
