# %% [markdown]
# logistic
# regression
# SVM
# Decision Tree
# Random Forest

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

# %%
df.head().T
# Out:
#                                   0                    1  \
# date            2014-05-02 00:00:00  2014-05-02 00:00:00
# price                      313000.0            2384000.0
# bedrooms                        3.0                  5.0
# bathrooms                       1.5                  2.5
# sqft_living                    1340                 3650
# sqft_lot                       7912                 9050
# floors                          1.5                  2.0
# waterfront                        0                    0
# view                              0                    4
# condition                         3                    5
# sqft_above                     1340                 3370
# sqft_basement                     0                  280
# yr_built                       1955                 1921
# yr_renovated                   2005                    0
# street         18810 Densmore Ave N      709 W Blaine St
# city                      Shoreline              Seattle
# statezip                   WA 98133             WA 98119
# country                         USA                  USA
#
#                                       2                    3  \
# date                2014-05-02 00:00:00  2014-05-02 00:00:00
# price                          342000.0             420000.0
# bedrooms                            3.0                  3.0
# bathrooms                           2.0                 2.25
# sqft_living                        1930                 2000
# sqft_lot                          11947                 8030
# floors                              1.0                  1.0
# waterfront                            0                    0
# view                                  0                    0
# condition                             4                    4
# sqft_above                         1930                 1000
# sqft_basement                         0                 1000
# yr_built                           1966                 1963
# yr_renovated                          0                    0
# street         26206-26214 143rd Ave SE      857 170th Pl NE
# city                               Kent             Bellevue
# statezip                       WA 98042             WA 98008
# country                             USA                  USA
#
#                                  4
# date           2014-05-02 00:00:00
# price                     550000.0
# bedrooms                       4.0
# bathrooms                      2.5
# sqft_living                   1940
# sqft_lot                     10500
# floors                         1.0
# waterfront                       0
# view                             0
# condition                        4
# sqft_above                    1140
# sqft_basement                  800
# yr_built                      1976
# yr_renovated                  1992
# street           9105 170th Ave NE
# city                       Redmond
# statezip                  WA 98052
# country                        USA

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df = df.drop(['date', 'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country'], axis=1)

# %%
df.head().T
# Out:
#                       0          1         2          3         4
# price          313000.0  2384000.0  342000.0  420000.00  550000.0
# bedrooms            3.0        5.0       3.0       3.00       4.0
# bathrooms           1.5        2.5       2.0       2.25       2.5
# sqft_living      1340.0     3650.0    1930.0    2000.00    1940.0
# sqft_lot         7912.0     9050.0   11947.0    8030.00   10500.0
# floors              1.5        2.0       1.0       1.00       1.0
# waterfront          0.0        0.0       0.0       0.00       0.0
# view                0.0        4.0       0.0       0.00       0.0
# condition           3.0        5.0       4.0       4.00       4.0
# sqft_above       1340.0     3370.0    1930.0    1000.00    1140.0
# sqft_basement       0.0      280.0       0.0    1000.00     800.0

# %% [markdown]
# fig, axes = plt.subplots(3, 4, figsize=(15, 10))
# axes = axes.ravel()
#
# # If X is a DataFrame, convert it to numpy array
# if isinstance(X, pd.DataFrame):
#     X = X.to_numpy()
#
# for i, feature in enumerate(df.columns):
#     axes[i].scatter(X[:, i], y)
#     axes[i].set_xlabel(feature)
#     axes[i].set_ylabel('Houses')
#
# plt.tight_layout()
# plt.show()

# %%
X = df.drop('price', axis=1)
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
